# %% [markdown]
# # Assignment 6
#
# ## Glen Quadros
# ## 202051211

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
female_pop_df = pd.read_csv('/Users/glenquadros/Desktop/Data Analysis and Visualization/Assignment 6/population_of_female.csv')

# %%
female_pop_df.tail()
# Out:
#      Country Name Country Code      Indicator Name     Indicator Code  \
# 261        Kosovo          XKX  Population, female  SP.POP.TOTL.FE.IN
# 262   Yemen, Rep.          YEM  Population, female  SP.POP.TOTL.FE.IN
# 263  South Africa          ZAF  Population, female  SP.POP.TOTL.FE.IN
# 264        Zambia          ZMB  Population, female  SP.POP.TOTL.FE.IN
# 265      Zimbabwe          ZWE  Population, female  SP.POP.TOTL.FE.IN
#
#           1960       1961       1962       1963       1964       1965  ...  \
# 261   466471.0   475714.0   489406.0   503107.0   516803.0   530503.0  ...
# 262  2776227.0  2830873.0  2887401.0  2944847.0  3005276.0  3069773.0  ...
# 263  8017980.0  8263745.0  8532023.0  8813888.0  9107018.0  9412255.0  ...
# 264  1574966.0  1626102.0  1679256.0  1734441.0  1791447.0  1850435.0  ...
# 265  1922334.0  1983717.0  2047197.0  2112858.0  2180688.0  2250818.0  ...
#
#            2012        2013        2014        2015        2016        2017  \
# 261    905096.0    910703.0    908173.0    896017.0    890797.0    897635.0
# 262  12950282.0  13323201.0  13700388.0  14077389.0  14453847.0  14831892.0
# 263  27493643.0  27837495.0  28228865.0  28721087.0  29004108.0  29175940.0
# 264   7499172.0   7743342.0   7993413.0   8247891.0   8507289.0   8772120.0
# 265   7041528.0   7192279.0   7347527.0   7502101.0   7656047.0   7810471.0
#
#            2018        2019        2020        2021
# 261    900766.0    896722.0    897541.0    895801.0
# 262  15211556.0  15593113.0  15963067.0  16313210.0
# 263  29517286.0  29879107.0  30221143.0  30497646.0
# 264   9041177.0   9314079.0   9589102.0   9864121.0
# 265   7966181.0   8122618.0   8284447.0   8449834.0
#
# [5 rows x 66 columns]

# %%
primary_comp_rate_female_df = pd.read_csv('/Users/glenquadros/Desktop/Data Analysis and Visualization/Assignment 6/primary_completion_rate_female.csv')

# %%
primary_comp_rate_female_df.tail()
# Out:
#      Country Name Country Code  \
# 261        Kosovo          XKX
# 262   Yemen, Rep.          YEM
# 263  South Africa          ZAF
# 264        Zambia          ZMB
# 265      Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 261  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 262  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 263  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 264  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 265  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
#
#      1960  1961  1962  1963  1964  1965  ...       2012       2013       2014  \
# 261   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 262   NaN   NaN   NaN   NaN   NaN   NaN  ...  60.151791  61.386909        NaN
# 263   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 264   NaN   NaN   NaN   NaN   NaN   NaN  ...  87.913467  78.582474        NaN
# 265   NaN   NaN   NaN   NaN   NaN   NaN  ...  97.962959  98.854950  97.411469
#
#            2015       2016       2017       2018       2019      2020  \
# 261         NaN        NaN        NaN        NaN        NaN       NaN
# 262         NaN  64.500092        NaN        NaN        NaN       NaN
# 263   89.105278  88.068489        NaN  92.124298  93.236481       NaN
# 264         NaN        NaN        NaN        NaN        NaN       NaN
# 265  100.912598  99.207138  96.014954  93.238541  89.320374  90.90255
#
#           2021
# 261        NaN
# 262        NaN
# 263        NaN
# 264        NaN
# 265  86.107933
#
# [5 rows x 66 columns]

# %% [markdown]
# ### 1. Create a column named “average_rate” in “primary_completion_rate_female.csv” that contains the average (over time) completion rate.

# %%
primary_comp_rate_female_df['average_rate'] = primary_comp_rate_female_df.mean(axis=1)
# Out:
# /var/folders/8q/hwngzqvx0871np5x0mj6_d9h0000gn/T/ipykernel_5439/3385295109.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   primary_comp_rate_female_df['average_rate'] = primary_comp_rate_female_df.mean(axis=1)

# %%
primary_comp_rate_female_df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 1    Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 2    Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 3    Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 4    Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# ..                                                 ...                ...
# 261  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 262  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 263  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 264  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
# 265  Primary completion rate, female (% of relevant...  SE.PRM.CMPT.FE.ZS
#
#      1960  1961  1962  1963  1964  1965  ...        2013        2014  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN  ...  101.255234  101.555870
# 1     NaN   NaN   NaN   NaN   NaN   NaN  ...   66.028069   66.263290
# 2     NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN         NaN
# 3     NaN   NaN   NaN   NaN   NaN   NaN  ...   64.063690   64.651100
# 4     NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN         NaN
# ..    ...   ...   ...   ...   ...   ...  ...         ...         ...
# 261   NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN         NaN
# 262   NaN   NaN   NaN   NaN   NaN   NaN  ...   61.386909         NaN
# 263   NaN   NaN   NaN   NaN   NaN   NaN  ...         NaN         NaN
# 264   NaN   NaN   NaN   NaN   NaN   NaN  ...   78.582474         NaN
# 265   NaN   NaN   NaN   NaN   NaN   NaN  ...   98.854950   97.411469
#
#            2015       2016       2017       2018       2019       2020  \
# 0           NaN        NaN        NaN        NaN        NaN        NaN
# 1     66.115013  66.932449  68.167793  69.499100  69.990547  70.825378
# 2           NaN  63.604069  66.688881  67.129303  65.761513        NaN
# 3     65.822060  66.608093  66.362289  66.722877  66.927361  67.231689
# 4           NaN        NaN        NaN        NaN        NaN        NaN
# ..          ...        ...        ...        ...        ...        ...
# 261         NaN        NaN        NaN        NaN        NaN        NaN
# 262         NaN  64.500092        NaN        NaN        NaN        NaN
# 263   89.105278  88.068489        NaN  92.124298  93.236481        NaN
# 264         NaN        NaN        NaN        NaN        NaN        NaN
# 265  100.912598  99.207138  96.014954  93.238541  89.320374  90.902550
#
#           2021  average_rate
# 0          NaN     96.203056
# 1          NaN     52.899081
# 2          NaN     28.085734
# 3          NaN     54.108691
# 4          NaN     34.111267
# ..         ...           ...
# 261        NaN           NaN
# 262        NaN     48.823942
# 263        NaN     88.622194
# 264        NaN     67.949980
# 265  86.107933     91.649270
#
# [266 rows x 67 columns]

# %% [markdown]
# ### 2. Create a column named “Latest Population” in “population_of_female.csv” that contains the latest population of females in the country.

# %%
female_pop_df['Latest Population'] = female_pop_df['2021']

# %%
female_pop_df.tail()
# Out:
#      Country Name Country Code      Indicator Name     Indicator Code  \
# 261        Kosovo          XKX  Population, female  SP.POP.TOTL.FE.IN
# 262   Yemen, Rep.          YEM  Population, female  SP.POP.TOTL.FE.IN
# 263  South Africa          ZAF  Population, female  SP.POP.TOTL.FE.IN
# 264        Zambia          ZMB  Population, female  SP.POP.TOTL.FE.IN
# 265      Zimbabwe          ZWE  Population, female  SP.POP.TOTL.FE.IN
#
#           1960       1961       1962       1963       1964       1965  ...  \
# 261   466471.0   475714.0   489406.0   503107.0   516803.0   530503.0  ...
# 262  2776227.0  2830873.0  2887401.0  2944847.0  3005276.0  3069773.0  ...
# 263  8017980.0  8263745.0  8532023.0  8813888.0  9107018.0  9412255.0  ...
# 264  1574966.0  1626102.0  1679256.0  1734441.0  1791447.0  1850435.0  ...
# 265  1922334.0  1983717.0  2047197.0  2112858.0  2180688.0  2250818.0  ...
#
#            2013        2014        2015        2016        2017        2018  \
# 261    910703.0    908173.0    896017.0    890797.0    897635.0    900766.0
# 262  13323201.0  13700388.0  14077389.0  14453847.0  14831892.0  15211556.0
# 263  27837495.0  28228865.0  28721087.0  29004108.0  29175940.0  29517286.0
# 264   7743342.0   7993413.0   8247891.0   8507289.0   8772120.0   9041177.0
# 265   7192279.0   7347527.0   7502101.0   7656047.0   7810471.0   7966181.0
#
#            2019        2020        2021  Latest Population
# 261    896722.0    897541.0    895801.0           895801.0
# 262  15593113.0  15963067.0  16313210.0         16313210.0
# 263  29879107.0  30221143.0  30497646.0         30497646.0
# 264   9314079.0   9589102.0   9864121.0          9864121.0
# 265   8122618.0   8284447.0   8449834.0          8449834.0
#
# [5 rows x 67 columns]

# %% [markdown]
# ### 3. What is the weighted average of primary rates of different countries? The weight should be the Latest population of females in the country.

# %%
weights = female_pop_df['Latest Population']/female_pop_df['Latest Population'].sum()

# %%
weights
# Out:
# 0      0.000001
# 1      0.008351
# 2      0.000467
# 3      0.005597
# 4      0.000411
#          ...
# 261    0.000021
# 262    0.000384
# 263    0.000718
# 264    0.000232
# 265    0.000199
# Name: Latest Population, Length: 266, dtype: float64

# %% [markdown]
# ### 4. What is the Median of average primary completion rate?

# %%
female_pop_df['Latest Population'].median()
# Out:
# 5368123.0

# %% [markdown]
# ### 5. What is the InterQuartile Range of average primary completion rate?

# %%
IQR = female_pop_df["Latest Population"].quantile(0.75) - female_pop_df["Latest Population"].quantile(0.25)

# %%
IQR
# Out:
# 31397807.0

# %% [markdown]
# ### 6. What is the Variance of average primary completion rate?

# %%
female_pop_df['Latest Population'].var()
# Out:
# 2.480701920448484e+17
